# %% [markdown]
# # Python para Engenharia de Dados
# ----

# %% [markdown]
# ### Bibliotecas de manipulação de dados (Pandas)
#
# * Biblioteca poderosa para manipulação e análise de dados estruturados;
# * Utilizada amplamente no processo de preparação de dados;
# * Permite funções de limpeza e manipulação de dados, como por exemplo o preenchimento, substituição ou inserção de valores nulos, exclusão de dados duplicados etc;
# * Permite a utilização de funções estatísticas para análise de dados.
# * Possui dois tipos de dados básicos:<p>
# • Series<br>
# • DataFrame<br>

# %% [markdown]
# ### Series
#
# Arranjos unidimensionais indexados, que podem conter elementos de tipos diversos (int, float, string, list etc.)

# %%
import pandas as pd
#Criando uma série indexada por valores inteiros, iniciando em 0
serie = pd.Series([10, 20, 43, 87, 3])
serie
# Out:
# 0    10
# 1    20
# 2    43
# 3    87
# 4     3
# dtype: int64

# %%
#Criando uma série indexada por letras
serie = pd.Series([10, 20, 43, 87, 3], index = ['a', 'b', 'c', 'd', 'e'])
serie
# Out:
# a    10
# b    20
# c    43
# d    87
# e     3
# dtype: int64

# %%
#Criando uma série indexada por nomes
serie = pd.Series([10, 20, 43, 87, 3], index = ['João', 'Maria', 'Pedro', 'Sílvia', 'Alex'])
serie
# Out:
# João      10
# Maria     20
# Pedro     43
# Sílvia    87
# Alex       3
# dtype: int64

# %%
#Transformando um dicionário em uma série
dicionario = {'João': 90, 'Maria': 86, 'André': 75, 'Carla': 94}
serie = pd.Series(dicionario)
serie
# Out:
# João     90
# Maria    86
# André    75
# Carla    94
# dtype: int64

# %%
import numpy as np
#Trabalhando com valores nulos
dicionario = {'João': 90, 'Maria': 86, 'André': 75, 'Carla': 94, 'Alex': np.NaN}

serie = pd.Series(dicionario)
print(serie)
print()
print(serie.isnull()) # Verificando os valores nulos na série
# Out:
# João     90.0
# Maria    86.0
# André    75.0
# Carla    94.0
# Alex      NaN
# dtype: float64
#
# João     False
# Maria    False
# André    False
# Carla    False
# Alex      True
# dtype: bool

# %%
funcionario = {'João': 1500, 'Maria': 2500, 'André': 3000.50, 'Carla': 4000.00, 'Alex': 30000.00}
serie = pd.Series(funcionario)
# Exibindo resumo estatístico da série
serie.describe()
#Ordenando a série pelo índice
serie.sort_index(inplace = True)
print(serie)
print()
#Ordenando a série pelo valor
serie.sort_values(inplace = True)
print(serie)
# Out:
# Alex     30000.0
# André     3000.5
# Carla     4000.0
# João      1500.0
# Maria     2500.0
# dtype: float64
#
# João      1500.0
# Maria     2500.0
# André     3000.5
# Carla     4000.0
# Alex     30000.0
# dtype: float64

# %%
funcionario = {'João': 1500, 'Maria': 2500, 'André': 3000.50, 'Carla': 4000.00, 'Alex': 30000.00}
serie = pd.Series(funcionario)
# Verificando se um índice se encontra na série
'João' in serie
#Retornando o valor para o índice 'Carla'
print(serie.loc['Carla'])
print(serie['Carla'])
#Retornando o valor para os índice 'Maria' e Carla'
print(serie.loc[['Carla', 'Maria']])
print(serie[['Carla', 'Maria']])
#Retornando o valor para o índice 0
print(serie.iloc[0])
print(serie[0])
#Retornando o valor para os índices 0 e 2
print(serie.iloc[[0,2]])
print(serie[[0,2]])
# Out:
# 4000.0
# 4000.0
# Carla    4000.0
# Maria    2500.0
# dtype: float64
# Carla    4000.0
# Maria    2500.0
# dtype: float64
# 1500.0
# 1500.0
# João     1500.0
# André    3000.5
# dtype: float64
# João     1500.0
# André    3000.5
# dtype: float64

# %%
uncionario = {'João': 1500, 'Maria': 2500, 'André': 3000.50, 'Carla': 4000.00, 'Alex': 30000.00}
serie = pd.Series(funcionario)
#Retornando os 3 primeiros registros da série
print(serie.loc['João':'André'])
print(serie['João':'André'])
print(serie.iloc[0:3])
print(serie[0:3])
print(serie.head(3))
#Retornando os 3 últimos registros da série
print(serie.tail(3))
print(serie[-3:])
# Out:
# João     1500.0
# Maria    2500.0
# André    3000.5
# dtype: float64
# João     1500.0
# Maria    2500.0
# André    3000.5
# dtype: float64
# João     1500.0
# Maria    2500.0
# André    3000.5
# dtype: float64
# João     1500.0
# Maria    2500.0
# André    3000.5
# dtype: float64
# João     1500.0
# Maria    2500.0
# André    3000.5
# dtype: float64
# André     3000.5
# Carla     4000.0
# Alex     30000.0
# dtype: float64
# André     3000.5
# Carla     4000.0
# Alex     30000.0
# dtype: float64

# %% [markdown]
# #### DataFrame: estrutura bidimensional, utilizada para armazenamento de dados

# %%
import pandas as pd
alunos = {'nome' : ['João', 'Maria', 'Carlos', 'Silvia', 'André', 'Juliana'],
'RA': [1000, 2000, 3000, 4000, 2700, 6000],
'sexo': ['M', 'F', 'M', 'F', 'M', 'F'],
'nota': [80.0, 90.0, 75.0, 100.0, 96.5, 98.5]
}
df = pd.DataFrame(alunos)
df #exibe todo o dataframe
df.head() #exibe os 5 primeiros registros
df.tail() #exibe os 5 últimos registros
df.describe() # resumo estatístico de todos os campos numéricos
# Out:
#                 RA        nota
# count     6.000000    6.000000
# mean   3116.666667   90.000000
# std    1732.531866   10.387492
# min    1000.000000   75.000000
# 25%    2175.000000   82.500000
# 50%    2850.000000   93.250000
# 75%    3750.000000   98.000000
# max    6000.000000  100.000000

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Notas.csv'
file_path = 'Notas.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
notas = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
notas.describe()
# Out:
#               D1         D2         D3
# count  10.000000   8.000000   9.000000
# mean   16.100000  16.000000  12.444444
# std     3.813718   4.375255   6.747427
# min     9.000000   9.000000   3.000000
# 25%    13.750000  14.500000   7.000000
# 50%    17.500000  16.500000  14.000000
# 75%    19.000000  20.000000  18.000000
# max    20.000000  20.000000  20.000000

# %%
# Imprimindo a quantidade de linhas e colunas
notas.shape
# Out:
# (10, 4)

# %%
# Exibindo as colunas
notas.columns
# Out:
# Index(['Aluno', 'D1', 'D2', 'D3'], dtype='object')

# %%
# Exibindo a quantidade de valores não nulos
notas.count()
# Out:
# Aluno    10
# D1       10
# D2        8
# D3        9
# dtype: int64

# %%
import numpy as np
#Incluido novas colunas
notas['Alternativa'] = np.NaN
notas['Final'] = 0
notas['Media'] = round((notas['D1'] + notas['D2'] + notas['D3'])/3, 2)
notas
# Out:
#        Aluno  D1    D2    D3  Alternativa  Final  Media
# 0      Maria  13  20.0  14.0          NaN      0  15.67
# 1       João  16  17.0  20.0          NaN      0  17.67
# 2       José  20  16.0  19.0          NaN      0  18.33
# 3  Alexandre  18  16.0   NaN          NaN      0    NaN
# 4      Paulo  19   9.0   7.0          NaN      0  11.67
# 5     Carlos   9  10.0  11.0          NaN      0  10.00
# 6      Pedro  11   NaN  18.0          NaN      0    NaN
# 7      Joana  19  20.0   3.0          NaN      0  14.00
# 8      Carla  17   NaN  17.0          NaN      0    NaN
# 9      Joana  19  20.0   3.0          NaN      0  14.00

# %%
#importando e colunas específicas e renomeando as mesmas
notas = pd.read_csv('Notas.csv', encoding = 'utf-8', delimiter = ';',
usecols = [0, 1], names = ['NomeAluno', 'NotaD1'])
notas
# Out:
#     NomeAluno NotaD1
# 0       Aluno     D1
# 1       Maria     13
# 2        João     16
# 3        José     20
# 4   Alexandre     18
# 5       Paulo     19
# 6      Carlos      9
# 7       Pedro     11
# 8       Joana     19
# 9       Carla     17
# 10      Joana     19

# %%
notas = pd.read_csv('Notas.csv', encoding = 'utf-8', delimiter = ';',
usecols = [0,1,3])
notas
# Out:
#        Aluno  D1    D3
# 0      Maria  13  14.0
# 1       João  16  20.0
# 2       José  20  19.0
# 3  Alexandre  18   NaN
# 4      Paulo  19   7.0
# 5     Carlos   9  11.0
# 6      Pedro  11  18.0
# 7      Joana  19   3.0
# 8      Carla  17  17.0
# 9      Joana  19   3.0

# %%
notas = pd.read_csv('Notas.csv', encoding = 'utf-8', delimiter = ';',
usecols = ['Aluno', 'D3'])
notas
# Out:
#        Aluno    D3
# 0      Maria  14.0
# 1       João  20.0
# 2       José  19.0
# 3  Alexandre   NaN
# 4      Paulo   7.0
# 5     Carlos  11.0
# 6      Pedro  18.0
# 7      Joana   3.0
# 8      Carla  17.0
# 9      Joana   3.0

# %%
# Verificando linhas duplicadas
notas.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
# Removendo linhas duplicadas
notas.drop_duplicates(inplace = True)
notas
# Out:
#        Aluno    D3
# 0      Maria  14.0
# 1       João  20.0
# 2       José  19.0
# 3  Alexandre   NaN
# 4      Paulo   7.0
# 5     Carlos  11.0
# 6      Pedro  18.0
# 7      Joana   3.0
# 8      Carla  17.0

# %%
import pandas as pd
alunos = {'nome' : ['João', 'Maria', 'Carlos', 'Silvia', 'André', 'Juliana', 'Alex'],
'RA': [1000, 2000, 3000, 4000, 2700, 6000, 1000],
'sexo': ['M', 'F', 'M', 'F', 'M', 'F', 'M'],
'nota': [80.0, 90.0, 75.0, 100.0, 96.5, 98.5, 90]
}
df = pd.DataFrame(alunos)
df
# Out:
#       nome    RA sexo   nota
# 0     João  1000    M   80.0
# 1    Maria  2000    F   90.0
# 2   Carlos  3000    M   75.0
# 3   Silvia  4000    F  100.0
# 4    André  2700    M   96.5
# 5  Juliana  6000    F   98.5
# 6     Alex  1000    M   90.0

# %%
# Verificando as linhas que possuem RA duplicado
df.duplicated(subset = ['RA'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# Exibindo uma cópia do DataFrame as linhas que possuem RA duplicado
df.drop_duplicates(subset = ['RA'])
# Out:
#       nome    RA sexo   nota
# 0     João  1000    M   80.0
# 1    Maria  2000    F   90.0
# 2   Carlos  3000    M   75.0
# 3   Silvia  4000    F  100.0
# 4    André  2700    M   96.5
# 5  Juliana  6000    F   98.5

# %%
# Removendo as linhas que possuem RA duplicado
df.drop_duplicates(subset = ['RA'], inplace = True)
df
# Out:
#       nome    RA sexo   nota
# 0     João  1000    M   80.0
# 1    Maria  2000    F   90.0
# 2   Carlos  3000    M   75.0
# 3   Silvia  4000    F  100.0
# 4    André  2700    M   96.5
# 5  Juliana  6000    F   98.5

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Notas.csv'
file_path = 'Notas.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
notas = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
notas.describe()
# Out:
#               D1         D2         D3
# count  10.000000   8.000000   9.000000
# mean   16.100000  16.000000  12.444444
# std     3.813718   4.375255   6.747427
# min     9.000000   9.000000   3.000000
# 25%    13.750000  14.500000   7.000000
# 50%    17.500000  16.500000  14.000000
# 75%    19.000000  20.000000  18.000000
# max    20.000000  20.000000  20.000000

# %%
#Exibindo somente as colunas Aluno e D3
notas[['Aluno', 'D3']]
# Out:
#        Aluno    D3
# 0      Maria  14.0
# 1       João  20.0
# 2       José  19.0
# 3  Alexandre   NaN
# 4      Paulo   7.0
# 5     Carlos  11.0
# 6      Pedro  18.0
# 7      Joana   3.0
# 8      Carla  17.0
# 9      Joana   3.0

# %%
#Exibindo os alunos que obtiveram nota D3 > 10
notas[(notas.D3 > 10)]
# Out:
#     Aluno  D1    D2    D3
# 0   Maria  13  20.0  14.0
# 1    João  16  17.0  20.0
# 2    José  20  16.0  19.0
# 5  Carlos   9  10.0  11.0
# 6   Pedro  11   NaN  18.0
# 8   Carla  17   NaN  17.0

# %%
#Exibindo o nome dos alunos, e as notas D1 e D3,
#para aqueles que obtiveram D3 maior que 10 e
#D1 menor que 10
notas[(notas['D3'] > 10) & (notas['D1'] < 10)][['Aluno', 'D3']]
notas[(notas.D3 > 10) & (notas.D1 < 10)][['Aluno', 'D3']]
# Out:
#     Aluno    D3
# 5  Carlos  11.0

# %%
# Utilizando o método query
notas.query('D3 > 10 and D1 < 10')[['Aluno', 'D3']]
# Out:
#     Aluno    D3
# 5  Carlos  11.0

# %%
# Verificando valores nulos
notas[(notas.D3.isnull()) & (notas.D2.notnull())][['Aluno', 'D3', 'D2']]
notas.query('D3.isnull() and not D2.isnull()')[['Aluno', 'D3', 'D2']]
# Out:
#        Aluno  D3    D2
# 3  Alexandre NaN  16.0

# %%
#Removendo linhas com valores nulos
notas.dropna()
notas.dropna(inplace = True)
notas
# Out:
#     Aluno  D1    D2    D3
# 0   Maria  13  20.0  14.0
# 1    João  16  17.0  20.0
# 2    José  20  16.0  19.0
# 4   Paulo  19   9.0   7.0
# 5  Carlos   9  10.0  11.0
# 7   Joana  19  20.0   3.0
# 9   Joana  19  20.0   3.0

# %%
#Removendo linhas que possuem somente a coluna D3 nula
notas.dropna(subset=['D3'])
# Out:
#     Aluno  D1    D2    D3
# 0   Maria  13  20.0  14.0
# 1    João  16  17.0  20.0
# 2    José  20  16.0  19.0
# 4   Paulo  19   9.0   7.0
# 5  Carlos   9  10.0  11.0
# 7   Joana  19  20.0   3.0
# 9   Joana  19  20.0   3.0

# %%
#Removendo colunas com valores nulos
notas.dropna(axis = 1)
notas.dropna(axis = 1, inplace = True)
notas
# Out:
#     Aluno  D1    D2    D3
# 0   Maria  13  20.0  14.0
# 1    João  16  17.0  20.0
# 2    José  20  16.0  19.0
# 4   Paulo  19   9.0   7.0
# 5  Carlos   9  10.0  11.0
# 7   Joana  19  20.0   3.0
# 9   Joana  19  20.0   3.0

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Notas.csv'
file_path = 'Notas.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
notas = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
notas.describe()
# Out:
#               D1         D2         D3
# count  10.000000   8.000000   9.000000
# mean   16.100000  16.000000  12.444444
# std     3.813718   4.375255   6.747427
# min     9.000000   9.000000   3.000000
# 25%    13.750000  14.500000   7.000000
# 50%    17.500000  16.500000  14.000000
# 75%    19.000000  20.000000  18.000000
# max    20.000000  20.000000  20.000000

# %%
# Recuperando as notas dos alunos Alexandre e Carlos
df = notas
df[df.Aluno.isin(['Alexandre', 'Carlos'])]
# Out:
#        Aluno  D1    D2    D3
# 3  Alexandre  18  16.0   NaN
# 5     Carlos   9  10.0  11.0

# %%
# Alunos que começam com Car
df[df.Aluno.str.startswith('Car')]
# Out:
#     Aluno  D1    D2    D3
# 5  Carlos   9  10.0  11.0
# 8   Carla  17   NaN  17.0

# %%
# Alunos que terminam com a
df[df.Aluno.str.endswith('a')]
# Out:
#    Aluno  D1    D2    D3
# 0  Maria  13  20.0  14.0
# 7  Joana  19  20.0   3.0
# 8  Carla  17   NaN  17.0
# 9  Joana  19  20.0   3.0

# %%
# Alunos que possuem Jo
df[df.Aluno.str.contains('Jo')][['Aluno', 'D3']]
# Out:
#    Aluno    D3
# 1   João  20.0
# 2   José  19.0
# 7  Joana   3.0
# 9  Joana   3.0

# %%
# Alunos que possuem jo
df[df.Aluno.str.lower().str.contains('jo')]
# Out:
#    Aluno  D1    D2    D3
# 1   João  16  17.0  20.0
# 2   José  20  16.0  19.0
# 7  Joana  19  20.0   3.0
# 9  Joana  19  20.0   3.0

# %%
# Atualizando a coluna com o nome de todos os alunos em maiúsculo
df['Aluno'] = df.Aluno.str.upper()
df
# Out:
#        Aluno  D1    D2    D3
# 0      MARIA  13  20.0  14.0
# 1       JOÃO  16  17.0  20.0
# 2       JOSÉ  20  16.0  19.0
# 3  ALEXANDRE  18  16.0   NaN
# 4      PAULO  19   9.0   7.0
# 5     CARLOS   9  10.0  11.0
# 6      PEDRO  11   NaN  18.0
# 7      JOANA  19  20.0   3.0
# 8      CARLA  17   NaN  17.0
# 9      JOANA  19  20.0   3.0

# %%
# Ordenando os dados pelo nome do Aluno
notas.sort_values(by = 'Aluno')
# Out:
#        Aluno  D1    D2    D3
# 3  ALEXANDRE  18  16.0   NaN
# 8      CARLA  17   NaN  17.0
# 5     CARLOS   9  10.0  11.0
# 7      JOANA  19  20.0   3.0
# 9      JOANA  19  20.0   3.0
# 2       JOSÉ  20  16.0  19.0
# 1       JOÃO  16  17.0  20.0
# 0      MARIA  13  20.0  14.0
# 4      PAULO  19   9.0   7.0
# 6      PEDRO  11   NaN  18.0

# %%
# Ordenando os dados pelo nome do Aluno em ordem decrescente
notas.sort_values(by = 'Aluno', ascending = False)
# Out:
#        Aluno  D1    D2    D3
# 6      PEDRO  11   NaN  18.0
# 4      PAULO  19   9.0   7.0
# 0      MARIA  13  20.0  14.0
# 1       JOÃO  16  17.0  20.0
# 2       JOSÉ  20  16.0  19.0
# 7      JOANA  19  20.0   3.0
# 9      JOANA  19  20.0   3.0
# 5     CARLOS   9  10.0  11.0
# 8      CARLA  17   NaN  17.0
# 3  ALEXANDRE  18  16.0   NaN

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Notas_Curso.csv'
file_path = 'Notas_Curso.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
notas = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
notas.describe()
# Out:
#               D1         D2         D3
# count  13.000000  13.000000  13.000000
# mean   15.461538  15.923077  17.000000
# std     4.012800   3.861380   4.041452
# min     8.000000   9.000000   7.000000
# 25%    13.000000  16.000000  17.000000
# 50%    17.000000  17.000000  18.000000
# 75%    19.000000  18.000000  20.000000
# max    20.000000  20.000000  20.000000

# %%
# Ordenando os dados pelo nome do Curso e do Aluno, em ordem crescente
notas.sort_values(by = ['Curso','Aluno'])
# Out:
#         Aluno  D1  D2  D3                               Curso Sexo
# 3   Alexandre  18  16  20            Engenharia da Computação    M
# 11   Carolina  15  10  20            Engenharia da Computação    F
# 2        José  20  16  19            Engenharia da Computação    M
# 1        João  16  17  20            Engenharia da Computação    M
# 4       Paulo   8   9   7            Engenharia da Computação    M
# 12    Roberto  17  18  20            Engenharia da Computação    M
# 10     Sílvia  19  20  17            Engenharia da Computação    F
# 5      Carlos   9  10  11  Engenharia de Controle e Automação    M
# 9       Joana  19  20  18  Engenharia de Controle e Automação    F
# 7       Paula  19  17  20  Engenharia de Controle e Automação    F
# 8       Carla  17  16  17              Sistemas de Informação    F
# 0       Maria  13  20  14              Sistemas de Informação    F
# 6       Pedro  11  18  18              Sistemas de Informação    M

# %%
# Ordenando os dados pelo nome do Curso em ordem decrescente, e do Aluno, em ordem crescente
notas.sort_values(by = ['Curso','Aluno'], ascending = [False, True])
# Out:
#         Aluno  D1  D2  D3                               Curso Sexo
# 8       Carla  17  16  17              Sistemas de Informação    F
# 0       Maria  13  20  14              Sistemas de Informação    F
# 6       Pedro  11  18  18              Sistemas de Informação    M
# 5      Carlos   9  10  11  Engenharia de Controle e Automação    M
# 9       Joana  19  20  18  Engenharia de Controle e Automação    F
# 7       Paula  19  17  20  Engenharia de Controle e Automação    F
# 3   Alexandre  18  16  20            Engenharia da Computação    M
# 11   Carolina  15  10  20            Engenharia da Computação    F
# 2        José  20  16  19            Engenharia da Computação    M
# 1        João  16  17  20            Engenharia da Computação    M
# 4       Paulo   8   9   7            Engenharia da Computação    M
# 12    Roberto  17  18  20            Engenharia da Computação    M
# 10     Sílvia  19  20  17            Engenharia da Computação    F

# %%
#Media das notas D1
print(notas['D1'].mean())
# Out:
# 15.461538461538462

# %%
#Maior nota da D2
print(notas['D2'].max())
# Out:
# 20

# %%
#Menor nota da D3
print(notas['D2'].min())
# Out:
# 9

# %%
# Quantidade de linhas por curso
notas['Curso'].value_counts()
# Out:
# Engenharia da Computação              7
# Sistemas de Informação                3
# Engenharia de Controle e Automação    3
# Name: Curso, dtype: int64

# %%
# Quantidade de linhas por sexo
notas['Sexo'].value_counts()
# Out:
# M    7
# F    6
# Name: Sexo, dtype: int64

# %%
# Quantidade de alunos por curso e sexo
notas.groupby(['Curso', 'Sexo']) ['Aluno'].count()
# Out:
# Curso                               Sexo
# Engenharia da Computação            F       2
#                                     M       5
# Engenharia de Controle e Automação  F       2
#                                     M       1
# Sistemas de Informação              F       2
#                                     M       1
# Name: Aluno, dtype: int64

# %%
# Média das notas por curso e sexo
notas.groupby(['Curso', 'Sexo']).mean().round(2)
# Out:
#                                            D1    D2    D3
# Curso                              Sexo
# Engenharia da Computação           F     17.0  15.0  18.5
#                                    M     15.8  15.2  17.2
# Engenharia de Controle e Automação F     19.0  18.5  19.0
#                                    M      9.0  10.0  11.0
# Sistemas de Informação             F     15.0  18.0  15.5
#                                    M     11.0  18.0  18.0

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Notas_Curso.csv'
file_path = 'Notas_Curso.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
notas = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
notas.describe()
# Out:
#               D1         D2         D3
# count  13.000000  13.000000  13.000000
# mean   15.461538  15.923077  17.000000
# std     4.012800   3.861380   4.041452
# min     8.000000   9.000000   7.000000
# 25%    13.000000  16.000000  17.000000
# 50%    17.000000  17.000000  18.000000
# 75%    19.000000  18.000000  20.000000
# max    20.000000  20.000000  20.000000

# %%
# Plotando gráfico de quantidade de alunos por Curso
notas['Curso'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
# Rotacionando o label
notas['Curso'].value_counts().plot(rot = 90)
notas['Curso'].value_counts().plot(title = 'Alunos por Curso', rot = 90).set(xlabel='Curso', ylabel='Qtd Alunos')
notas['Curso'].value_counts().plot(kind = 'bar', title = 'Alunos por Curso', rot = 90).set(xlabel='Curso', ylabel='QtdAlunos')
# Out:
# [Text(0.5, 0, 'Curso'), Text(0, 0.5, 'QtdAlunos')]

# %%
import pandas as pd
import urllib.request

file_url = 'https://github.com/Adrianogvs/014-Pos-Graduacao-Engenharia-de-Dados/raw/main/data/Temperatura.csv'
file_path = 'Temperatura.csv'

# Baixar o arquivo CSV
urllib.request.urlretrieve(file_url, file_path)

# Ler o arquivo CSV
temp = pd.read_csv(file_path, encoding='utf-8', delimiter=';')
temp.describe()
# Out:
#        temperatura
# count    37.000000
# mean     25.351351
# std       4.510581
# min      17.000000
# 25%      21.000000
# 50%      27.000000
# 75%      29.000000
# max      32.000000

# %%
temp.sample(5)
# Out:
#                  cidade estado data_coleta  temperatura
# 14       Belo Horizonte     MG  26/01/2020           23
# 27  São josé dos Campos     SP  21/01/2020           22
# 8        Belo Horizonte     MG  20/01/2020           25
# 29  São josé dos Campos     SP  23/01/2020           20
# 25         Juiz de Fora     MG  26/01/2020           30

# %%
temp.groupby('cidade').mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='cidade'>

# %%
t = temp[(temp.cidade == 'Belo Horizonte') & (temp.data_coleta >= '21/01/2020') & (temp.data_coleta <= '25/01/2020')]
t.plot(kind='line',x='data_coleta',y='temperatura', title = 'Temperatura de BH').set(xlabel='Dia',ylabel='Temperatura')
# Out:
# [Text(0.5, 0, 'Dia'), Text(0, 0.5, 'Temperatura')]

# %% [markdown]
# #### Referências
# • Principles and Techniques of Data Science
# Chapter 3: Tabular Data
# https://www.textbook.ds100.org
